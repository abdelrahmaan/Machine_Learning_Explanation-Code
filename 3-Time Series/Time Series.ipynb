# %% [markdown]
# # for represention data

# %%
import pandas as pd

# %%
print(pd.to_datetime('2018-01-15 3:45pm'))
print(pd.to_datetime('7/8/1952'))
print(pd.to_datetime('30/8/1952', dayfirst=True))
print(pd.to_datetime(['2018-01-05', '7/8/1952', 'Oct 10, 1995']))
print(pd.to_datetime(['2/25/10', '8/6/17', '12/15/12'], format='%m/%d/%y'))
# Out:
# 2018-01-15 15:45:00
# 1952-07-08 00:00:00
# 1952-08-30 00:00:00
# DatetimeIndex(['2018-01-05', '1952-07-08', '1995-10-10'], dtype='datetime64[ns]', freq=None)
# DatetimeIndex(['2010-02-25', '2017-08-06', '2012-12-15'], dtype='datetime64[ns]', freq=None)

# %%
opsd_daily = pd.read_csv('opsd_germany_daily.csv')
opsd_daily.shape
# Out:
# (4383, 5)

# %%
opsd_daily.head()
# Out:
#          Date  Consumption  Wind  Solar  Wind+Solar
# 0  2006-01-01     1069.184   NaN    NaN         NaN
# 1  2006-01-02     1380.521   NaN    NaN         NaN
# 2  2006-01-03     1442.533   NaN    NaN         NaN
# 3  2006-01-04     1457.217   NaN    NaN         NaN
# 4  2006-01-05     1477.131   NaN    NaN         NaN

# %%
opsd_daily.dtypes
# Out:
# Date            object
# Consumption    float64
# Wind           float64
# Solar          float64
# Wind+Solar     float64
# dtype: object

# %%
opsd_daily = pd.read_csv('opsd_germany_daily.csv', index_col=0,
                         parse_dates=True)
opsd_daily.head()
# Out:
#             Consumption  Wind  Solar  Wind+Solar
# Date
# 2006-01-01     1069.184   NaN    NaN         NaN
# 2006-01-02     1380.521   NaN    NaN         NaN
# 2006-01-03     1442.533   NaN    NaN         NaN
# 2006-01-04     1457.217   NaN    NaN         NaN
# 2006-01-05     1477.131   NaN    NaN         NaN

# %%
# Add columns with year, month, and weekday name
opsd_daily['Year'] = opsd_daily.index.year
opsd_daily['Month'] = opsd_daily.index.month
opsd_daily['Weekday Name'] = opsd_daily.index.weekday_name
opsd_daily.head()
# Out:
#             Consumption  Wind  Solar  Wind+Solar  Year  Month Weekday Name
# Date
# 2006-01-01     1069.184   NaN    NaN         NaN  2006      1       Sunday
# 2006-01-02     1380.521   NaN    NaN         NaN  2006      1       Monday
# 2006-01-03     1442.533   NaN    NaN         NaN  2006      1      Tuesday
# 2006-01-04     1457.217   NaN    NaN         NaN  2006      1    Wednesday
# 2006-01-05     1477.131   NaN    NaN         NaN  2006      1     Thursday

# %%
# Display a random sampling of 5 rows
opsd_daily.sample(5, random_state=0)
# Out:
#             Consumption    Wind    Solar  Wind+Solar  Year  Month Weekday Name
# Date
# 2008-08-23     1152.011     NaN      NaN         NaN  2008      8     Saturday
# 2013-08-08     1291.984  79.666   93.371     173.037  2013      8     Thursday
# 2009-08-27     1281.057     NaN      NaN         NaN  2009      8     Thursday
# 2015-10-02     1391.050  81.229  160.641     241.870  2015     10       Friday
# 2009-06-02     1201.522     NaN      NaN         NaN  2009      6      Tuesday

# %%
opsd_daily.loc['2017-08-30']
# Out:
# Consumption       1434.05
# Wind              190.435
# Solar             152.124
# Wind+Solar        342.559
# Year                 2017
# Month                   8
# Weekday Name    Wednesday
# Name: 2017-08-30 00:00:00, dtype: object

# %%
opsd_daily.loc['2012-02']
# Out:
#             Consumption     Wind   Solar  Wind+Solar  Year  Month Weekday Name
# Date
# 2012-02-01     1511.866  199.607  43.502     243.109  2012      2    Wednesday
# 2012-02-02     1563.407   73.469  44.675     118.144  2012      2     Thursday
# 2012-02-03     1563.631   36.352  46.510      82.862  2012      2       Friday
# 2012-02-04     1372.614   20.551  45.225      65.776  2012      2     Saturday
# 2012-02-05     1279.432   55.522  54.572     110.094  2012      2       Sunday
# 2012-02-06     1574.766   34.896  55.389      90.285  2012      2       Monday
# 2012-02-07     1615.078  100.312  19.867     120.179  2012      2      Tuesday
# 2012-02-08     1613.774   93.763  36.930     130.693  2012      2    Wednesday
# 2012-02-09     1591.532  132.219  19.042     151.261  2012      2     Thursday
# 2012-02-10     1581.287   52.122  34.873      86.995  2012      2       Friday
# 2012-02-11     1377.404   32.375  44.629      77.004  2012      2     Saturday
# 2012-02-12     1264.254   62.659  45.176     107.835  2012      2       Sunday
# 2012-02-13     1561.987   25.984  11.287      37.271  2012      2       Monday
# 2012-02-14     1550.366  146.495   9.610     156.105  2012      2      Tuesday
# 2012-02-15     1476.037  413.367  18.877     432.244  2012      2    Wednesday
# 2012-02-16     1504.119  130.247  38.176     168.423  2012      2     Thursday
# 2012-02-17     1438.857  196.515  17.328     213.843  2012      2       Friday
# 2012-02-18     1236.069  237.889  26.248     264.137  2012      2     Saturday
# 2012-02-19     1107.431  272.655  30.382     303.037  2012      2       Sunday
# 2012-02-20     1401.873  160.315  53.794     214.109  2012      2       Monday
# 2012-02-21     1434.533  281.909  57.984     339.893  2012      2      Tuesday
# 2012-02-22     1453.507  287.635  74.904     362.539  2012      2    Wednesday
# 2012-02-23     1427.402  353.510  18.927     372.437  2012      2     Thursday
# 2012-02-24     1373.800  382.777  29.281     412.058  2012      2       Friday
# 2012-02-25     1133.184  302.102  42.667     344.769  2012      2     Saturday
# 2012-02-26     1086.743   95.234  37.214     132.448  2012      2       Sunday
# 2012-02-27     1436.095   86.956  43.099     130.055  2012      2       Monday
# 2012-02-28     1408.211  231.923  16.190     248.113  2012      2      Tuesday
# 2012-02-29     1434.062   77.024  30.360     107.384  2012      2    Wednesday

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(rc={'figure.figsize':(7, 4)})

opsd_daily['Consumption'].plot(linewidth=0.2);

# %%
opsd_daily['Solar'].plot(linewidth=0.2);

# %%
opsd_daily['Wind'].plot(linewidth=0.2);

# %%
cols_plot = ['Consumption', 'Solar', 'Wind']
axes = opsd_daily[cols_plot].plot(marker='.', alpha=0.2, linestyle='None', 
                 figsize=(7,4), subplots=True)

# %%
for ax in axes:
    ax.set_ylabel('Daily Totals (GWh)')

ax = opsd_daily.loc['2017', 'Consumption'].plot()
ax.set_ylabel('Daily Consumption (GWh)');

# %%
ax = opsd_daily.loc['2017-01':'2017-02', 'Consumption'].plot(marker='o', linestyle='-')
ax.set_ylabel('Daily Consumption (GWh)');

# %%
fig, ax = plt.subplots()
ax.plot(opsd_daily.loc['2017-01':'2017-02', 'Consumption'], marker='o', linestyle='-')
ax.set_ylabel('Daily Consumption (GWh)')
ax.set_title('Jan-Feb 2017 Electricity Consumption')
# Out:
# Text(0.5, 1.0, 'Jan-Feb 2017 Electricity Consumption')

# %%
fig, axes = plt.subplots(3, 1, figsize=(7, 6), sharex=True)
for name, ax in zip(['Consumption', 'Solar', 'Wind'], axes):
    sns.boxplot(data=opsd_daily, x='Month', y=name, ax=ax)
    ax.set_ylabel('GWh')
    ax.set_title(name)
    
# Remove the automatic x-axis label from all but the bottom subplot
if ax != axes[-1]:
    ax.set_xlabel('')

# %%
sns.boxplot(data=opsd_daily, x='Weekday Name', y='Consumption');

# %%
sns.boxplot(data=opsd_daily, x='Weekday Name', y='Solar');

# %%
sns.boxplot(data=opsd_daily, x='Weekday Name', y='Wind');

# %% [markdown]
#  # processing on  data

# %%
from statsmodels.tsa.ar_model import AR 
from statsmodels.tsa.arima_model import ARMA  
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.vector_ar.var_model import VAR
from random import random

# %%
# AR example

# contrived dataset
xdata = range(1, 100)
ydata = [x + (3*random()) for x in xdata]
plt.xlim(0, 100)
plt.ylim(0, 100)

plt.scatter(xdata,ydata,s=10)
plt.show()

# %%
# fit model
model = AR(ydata)
model_fit = model.fit()

# make prediction
#yhat = model_fit.predict(len(xdata), len(ydata))
yhat = model_fit.predict( start= 90, end = 110 )
print('Predicted value for Auto Regression ', yhat)
# Out:
# Predicted value for Auto Regression  [ 92.09074772  94.06351998  95.12463473  95.97183863  97.43879445
#   96.85154693  98.52407055  99.46805755 100.8253293  102.21491774
#  103.18312048 103.44467236 104.80200107 105.8891191  106.64607384
#  107.45548088 108.22414629 109.45353405 110.52322883 111.78448852
#  113.15390373]

# %%
# MA example

# fit model
model = ARMA(ydata, order=(0, 1))
model_fit = model.fit(disp=False)
# make prediction
yhat = model_fit.predict( start= 90, end = 110 )
print('Predicted value for Moving Average 0,1 ',yhat)
# Out:
# Predicted value for Moving Average 0,1  [69.5909106  73.24701296 72.421858   74.29179381 73.42625405 74.08620622
#  73.6176949  75.62780991 74.73493595 77.10429232 51.42679948 51.42679948
#  51.42679948 51.42679948 51.42679948 51.42679948 51.42679948 51.42679948
#  51.42679948 51.42679948 51.42679948]

# %%
# ARMA example
newdata = [random() for x in range(1, 100)]

# change order
model = ARMA(newdata, order=(2, 1))
model_fit = model.fit(disp=False)
# make prediction
yhat = model_fit.predict( start= 90, end = 110 )
print('Predicted value for Moving Average 2,1 ',yhat)
# Out:
# Predicted value for Moving Average 2,1  [0.51191317 0.50013292 0.52448684 0.49016543 0.52231943 0.49829429
#  0.52561611 0.51771585 0.49303718 0.47726759 0.50671135 0.51614993
#  0.51154931 0.51273874 0.51252685 0.51254823 0.51255014 0.51254853
#  0.51254901 0.51254891 0.51254892]

# %%
# contrived dataset
data = [x + random() for x in range(1, 100)]
# fit model
model = SARIMAX(data, order=(1, 1, 1), seasonal_order=(1, 1, 1, 1))
model_fit = model.fit(disp=False)
# make prediction
yhat = model_fit.predict( start= 90, end = 110 )
print('Predicted value using SARIMAX ',yhat)
# Out:
# /Users/fox/anaconda3/envs/newEnv/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:961: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /Users/fox/anaconda3/envs/newEnv/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:993: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# Predicted value using SARIMAX  [ 91.45277946  92.43407629  93.44374008  94.46977904  95.43530662
#   96.45892675  97.45372981  98.42244598  99.44859051 100.42384912
#  101.46139731 102.45906101 103.4587287  104.45830635 105.4578878
#  106.45746909 107.45705039 108.45663169 109.45621299 110.45579428
#  111.45537558]

# %%
# VAR example


# contrived dataset with dependency
data = []
for i in range(100):
    v1 = i + random()
    v2 = v1 + random()
    row = [v1, v2]
    data.append(row)
    
data    
# fit model
model = VAR(data)
model_fit = model.fit()
# make prediction
yhat = model_fit.forecast(model_fit.y, steps=1)
print('Predicted value using VAR ',yhat)
# Out:
# Predicted value using VAR  [[100.22895754 100.68819455]]
# /Users/fox/anaconda3/envs/newEnv/lib/python3.7/site-packages/statsmodels/base/wrapper.py:35: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)

# %% [markdown]
# # new Example

# %%
# Import packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set()

# %%
df = pd.read_csv('multiTimeline.csv', skiprows=1)
df.head()
# Out:
#      Month  diet: (Worldwide)  gym: (Worldwide)  finance: (Worldwide)
# 0  2004-01                100                31                    48
# 1  2004-02                 75                26                    49
# 2  2004-03                 67                24                    47
# 3  2004-04                 70                22                    48
# 4  2004-05                 72                22                    43

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168 entries, 0 to 167
# Data columns (total 4 columns):
# Month                   168 non-null object
# diet: (Worldwide)       168 non-null int64
# gym: (Worldwide)        168 non-null int64
# finance: (Worldwide)    168 non-null int64
# dtypes: int64(3), object(1)
# memory usage: 5.3+ KB

# %%
df.columns = ['month', 'diet', 'gym', 'finance']
df.head()
# Out:
#      month  diet  gym  finance
# 0  2004-01   100   31       48
# 1  2004-02    75   26       49
# 2  2004-03    67   24       47
# 3  2004-04    70   22       48
# 4  2004-05    72   22       43

# %%
df.month = pd.to_datetime(df.month)
df.set_index('month', inplace=True)
df.head()
# Out:
#             diet  gym  finance
# month
# 2004-01-01   100   31       48
# 2004-02-01    75   26       49
# 2004-03-01    67   24       47
# 2004-04-01    70   22       48
# 2004-05-01    72   22       43

# %%
df.plot(figsize=(7,4), linewidth=1, fontsize=10)
plt.xlabel('Year', fontsize=10);

# %%
df[['diet']].plot(figsize=(7,4), linewidth=1, fontsize=10)
plt.xlabel('Year', fontsize=10);

# %%
diet = df[['diet']]
diet.rolling(12).mean().plot(figsize=(7,4), linewidth=1, fontsize=10)
plt.xlabel('Year', fontsize=10);

# %%
gym = df[['gym']]
gym.rolling(12).mean().plot(figsize=(7,4), linewidth=1, fontsize=10)
plt.xlabel('Year', fontsize=10);

# %%
df_rm = pd.concat([diet.rolling(12).mean(), gym.rolling(12).mean()], axis=1)
df_rm.plot(figsize=(7,4), linewidth=1, fontsize=10)
plt.xlabel('Year', fontsize=10);

# %%
diet.diff().plot(figsize=(7,4), linewidth=1, fontsize=10)
plt.xlabel('Year', fontsize=10);

# %%
df.plot(figsize=(7,4), linewidth=1, fontsize=10)
plt.xlabel('Year', fontsize=10)
# Out:
# Text(0.5, 0, 'Year')

# %%
df.corr()
# Out:
#              diet       gym   finance
# diet     1.000000 -0.100764 -0.034639
# gym     -0.100764  1.000000 -0.284279
# finance -0.034639 -0.284279  1.000000

# %%
df.diff().plot(figsize=(7,4), linewidth=1, fontsize=10)
plt.xlabel('Year', fontsize=10)
# Out:
# Text(0.5, 0, 'Year')

# %%
df.diff().corr()
# Out:
#              diet       gym   finance
# diet     1.000000  0.758707  0.373828
# gym      0.758707  1.000000  0.301111
# finance  0.373828  0.301111  1.000000

# %%
pd.plotting.autocorrelation_plot(diet);
